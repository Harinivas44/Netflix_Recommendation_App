# %%
import pandas as pd
import numpy as np

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# <ipython-input-244-ccc3fdad469d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 273  D E C E M B E R         25             Holmes & Watson
# 274  D E C E M B E R         25                        Vice
# 275  D E C E M B E R         25         On the Basis of Sex
# 276  D E C E M B E R         25                   Destroyer
# 277  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 273  Columbia Pictures / Gary Sanchez Productions /...
# 274          Annapurna Pictures / Plan B Entertainment
# 275                                     Focus Features
# 276                                 Annapurna Pictures
# 277                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 273  Etan Cohen (director/screenplay); Will Ferrell...
# 274  Adam McKay (director/screenplay); Christian Ba...
# 275  Mimi Leder (director); Daniel Stiepleman (scre...
# 276  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 277  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 273  [167]
# 274  [140]
# 275  [233]
# 276  [266]
# 277  [267]
#
# [278 rows x 7 columns]

# %% [markdown]
# As it is observed in the above table, we do not have the genre column so we will get the genre data from IMDb. You will need to create an API key in order to access the API key.

# %%
pip install tmdbv3api
# Out:
# Requirement already satisfied: tmdbv3api in /usr/local/lib/python3.10/dist-packages (1.9.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from tmdbv3api) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->tmdbv3api) (2023.7.22)

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '55660d08c6027c476324ca215b88fcbc'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x): #pass in the title of the movies
    genres = []
    result = tmdb_movie.search(x) #the title will be searched in the tmdb_movie
    movie_id = result[0].id #we will match the "id" with the "title"
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key)) #we will get the result from the IMDb data
    data_json = response.json() #we will then convert it to a json file
    if data_json['genres']: #in the json file we will only need to extract the "genre"
        genre_str = " "
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name']) #we will then add the "genre" to the empty genre list we created above
        return genre_str.join(genres)
    else:
        np.NaN # we will return the results but if we don't find anything we will consider it as a missing value

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1                       Title  \
# 0      J A N U A R Y          5     Insidious: The Last Key
# 1      J A N U A R Y          5            The Strange Ones
# 2      J A N U A R Y          5                    Stratton
# 3      J A N U A R Y         10               Sweet Country
# 4      J A N U A R Y         12                The Commuter
# ..               ...        ...                         ...
# 273  D E C E M B E R         25             Holmes & Watson
# 274  D E C E M B E R         25                        Vice
# 275  D E C E M B E R         25         On the Basis of Sex
# 276  D E C E M B E R         25                   Destroyer
# 277  D E C E M B E R         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                        Momentum Pictures / GFM Films
# 3                                 Samuel Goldwyn Films
# 4        Lionsgate / StudioCanal / The Picture Company
# ..                                                 ...
# 273  Columbia Pictures / Gary Sanchez Productions /...
# 274          Annapurna Pictures / Plan B Entertainment
# 275                                     Focus Features
# 276                                 Annapurna Pictures
# 277                                            Netflix
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 273  Etan Cohen (director/screenplay); Will Ferrell...
# 274  Adam McKay (director/screenplay); Christian Ba...
# 275  Mimi Leder (director); Daniel Stiepleman (scre...
# 276  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 277  David Slade (director); Charlie Brooker (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
# 276                                                NaN
# 277                                                NaN
#
#       Ref.                                           genres
# 0      NaN                          Horror Mystery Thriller
# 1      NaN                                   Thriller Drama
# 2      NaN                                  Action Thriller
# 3      NaN                     Western Crime Thriller Drama
# 4      NaN                          Action Thriller Mystery
# ..     ...                                              ...
# 273  [167]                   Mystery Adventure Comedy Crime
# 274  [140]        Thriller Science Fiction Action Adventure
# 275  [233]                                    Drama History
# 276  [266]                      Thriller Crime Drama Action
# 277  [267]  Science Fiction Mystery Drama Thriller TV Movie
#
# [278 rows x 8 columns]

# %%
df['Opening']=df['Opening'].str.replace(' ','')

# %%
df_2018 = df[['Title','Cast and crew','genres']]
df_2018
# Out:
#                           Title  \
# 0       Insidious: The Last Key
# 1              The Strange Ones
# 2                      Stratton
# 3                 Sweet Country
# 4                  The Commuter
# ..                          ...
# 273             Holmes & Watson
# 274                        Vice
# 275         On the Basis of Sex
# 276                   Destroyer
# 277  Black Mirror: Bandersnatch
#
#                                          Cast and crew  \
# 0    Adam Robitel (director); Leigh Whannell (scree...
# 1    Lauren Wolkstein (director); Christopher Radcl...
# 2    Simon West (director); Duncan Falconer, Warren...
# 3    Warwick Thornton (director); David Tranter, St...
# 4    Jaume Collet-Serra (director); Byron Willinger...
# ..                                                 ...
# 273  Etan Cohen (director/screenplay); Will Ferrell...
# 274  Adam McKay (director/screenplay); Christian Ba...
# 275  Mimi Leder (director); Daniel Stiepleman (scre...
# 276  Karyn Kusama (director); Phil Hay, Matt Manfre...
# 277  David Slade (director); Charlie Brooker (scree...
#
#                                               genres
# 0                            Horror Mystery Thriller
# 1                                     Thriller Drama
# 2                                    Action Thriller
# 3                       Western Crime Thriller Drama
# 4                            Action Thriller Mystery
# ..                                               ...
# 273                   Mystery Adventure Comedy Crime
# 274        Thriller Science Fiction Action Adventure
# 275                                    Drama History
# 276                      Thriller Crime Drama Action
# 277  Science Fiction Mystery Drama Thriller TV Movie
#
# [278 rows x 3 columns]

# %%
# Extract Directors
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-252-4838efec492a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['director_name'] = df_2018['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                          genres       director_name
# 0       Horror Mystery Thriller        Adam Robitel
# 1                Thriller Drama    Lauren Wolkstein
# 2               Action Thriller          Simon West
# 3  Western Crime Thriller Drama    Warwick Thornton
# 4       Action Thriller Mystery  Jaume Collet-Serra

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-255-94b1a1569c5d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_1_name'] = df_2018['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-257-75f2be6b779a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_2_name'] = df_2018['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-259-c6969dc4d5e1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2018['actor_3_name'] = df_2018['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2018.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                          genres       director_name    actor_1_name  \
# 0       Horror Mystery Thriller        Adam Robitel       Lin Shaye
# 1                Thriller Drama    Lauren Wolkstein   Alex Pettyfer
# 2               Action Thriller          Simon West  Dominic Cooper
# 3  Western Crime Thriller Drama    Warwick Thornton     Bryan Brown
# 4       Action Thriller Mystery  Jaume Collet-Serra     Liam Neeson
#
#              actor_2_name    actor_3_name
# 0           Angus Sampson  Leigh Whannell
# 1  James Freedson-Jackson   Emily Althaus
# 2          Austin Stowell      Gemma Chan
# 3               Sam Neill             NaN
# 4            Vera Farmiga  Patrick Wilson

# %%
df_2018 = df_2018.rename(columns={'Title':'movie_title'})

# %%
new_df18 = df_2018.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df18['actor_1_name'] = new_df18['actor_1_name'].replace(np.nan, 'unknown')
new_df18['actor_2_name'] = new_df18['actor_2_name'].replace(np.nan, 'unknown')
new_df18['actor_3_name'] = new_df18['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df18['movie_title'] = new_df18['movie_title'].str.lower()

# %%
new_df18['comb'] = new_df18['actor_1_name'] + ' ' + new_df18['actor_2_name'] + ' '+ new_df18['actor_3_name'] + ' '+ new_df18['director_name'] +' ' + new_df18['genres']
new_df18.head()
# Out:
#         director_name    actor_1_name            actor_2_name    actor_3_name  \
# 0        Adam Robitel       Lin Shaye           Angus Sampson  Leigh Whannell
# 1    Lauren Wolkstein   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2          Simon West  Dominic Cooper          Austin Stowell      Gemma Chan
# 3    Warwick Thornton     Bryan Brown               Sam Neill         unknown
# 4  Jaume Collet-Serra     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                          genres              movie_title  \
# 0       Horror Mystery Thriller  insidious: the last key
# 1                Thriller Drama         the strange ones
# 2               Action Thriller                 stratton
# 3  Western Crime Thriller Drama            sweet country
# 4       Action Thriller Mystery             the commuter
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# 2  Dominic Cooper Austin Stowell Gemma Chan Simon...
# 3  Bryan Brown Sam Neill unknown Warwick Thornton...
# 4  Liam Neeson Vera Farmiga Patrick Wilson Jaume ...

# %%
# Extract Data For 2019 movies
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# <ipython-input-267-ccc3fdad469d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 241  D E C E M B E R         25  Spies in Disguise
# 242  D E C E M B E R         25       Little Women
# 243  D E C E M B E R         25               1917
# 244  D E C E M B E R         25         Just Mercy
# 245  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 241  20th Century Fox / Blue Sky Studios / Chernin ...
# 242            Columbia Pictures / Regency Enterprises
# 243           Universal Pictures / DreamWorks Pictures
# 244          Warner Bros. Pictures / Participant Media
# 245                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 241  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 242  Greta Gerwig (director/screenplay); Saoirse Ro...  [225]
# 243  Sam Mendes (director/screenplay); Krysty Wilso...  [226]
# 244  Destin Daniel Cretton (director/screenplay), A...  [227]
# 245  Chinonye Chukwu (director/screenplay); Alfre W...  [228]
#
# [246 rows x 6 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#              Opening  Opening.1              Title  \
# 0      J A N U A R Y          4        Escape Room
# 1      J A N U A R Y          4         Rust Creek
# 2      J A N U A R Y          4   American Hangman
# 3      J A N U A R Y         11   A Dog's Way Home
# 4      J A N U A R Y         11         The Upside
# ..               ...        ...                ...
# 241  D E C E M B E R         25  Spies in Disguise
# 242  D E C E M B E R         25       Little Women
# 243  D E C E M B E R         25               1917
# 244  D E C E M B E R         25         Just Mercy
# 245  D E C E M B E R         27           Clemency
#
#                                     Production company  \
# 0                    Columbia Pictures / Original Film
# 1                       IFC Films / Lunacy Productions
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 241  20th Century Fox / Blue Sky Studios / Chernin ...
# 242            Columbia Pictures / Regency Enterprises
# 243           Universal Pictures / DreamWorks Pictures
# 244          Warner Bros. Pictures / Participant Media
# 245                                               Neon
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 241  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 242  Greta Gerwig (director/screenplay); Saoirse Ro...  [225]
# 243  Sam Mendes (director/screenplay); Krysty Wilso...  [226]
# 244  Destin Daniel Cretton (director/screenplay), A...  [227]
# 245  Chinonye Chukwu (director/screenplay); Alfre W...  [228]
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 241  Animation Action Adventure Comedy Family
# 242                             Drama Romance
# 243                          War Action Drama
# 244                       Drama Crime History
# 245                                     Drama
#
# [246 rows x 7 columns]

# %%
df['Opening']=df['Opening'].str.replace(' ','')

# %%
df_2019 = df[['Title','Cast and crew','genres']]
df_2019
# Out:
#                  Title                                      Cast and crew  \
# 0          Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1           Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2     American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3     A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4           The Upside  Neil Burger (director); Jon Hartmere (screenpl...
# ..                 ...                                                ...
# 241  Spies in Disguise  Nick Bruno, Troy Quane (directors); Brad Copel...
# 242       Little Women  Greta Gerwig (director/screenplay); Saoirse Ro...
# 243               1917  Sam Mendes (director/screenplay); Krysty Wilso...
# 244         Just Mercy  Destin Daniel Cretton (director/screenplay), A...
# 245           Clemency  Chinonye Chukwu (director/screenplay); Alfre W...
#
#                                        genres
# 0                     Horror Thriller Mystery
# 1                 Thriller Drama Action Crime
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 241  Animation Action Adventure Comedy Family
# 242                             Drama Romance
# 243                          War Action Drama
# 244                       Drama Crime History
# 245                                     Drama
#
# [246 rows x 3 columns]

# %%
# Extract Directors
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-272-84d0c3ababbd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['director_name'] = df_2019['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                         genres         director_name
# 0      Horror Thriller Mystery          Adam Robitel
# 1  Thriller Drama Action Crime           Jen McGowan
# 2                     Thriller     Wilson Coneybeare
# 3       Drama Adventure Family  Charles Martin Smith
# 4                 Comedy Drama           Neil Burger

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-275-eee71c5586b8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_1_name'] = df_2019['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-277-48d0aadc78c0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['actor_2_name'] = df_2019['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2019['actor_3_name'] = df_2019['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2019.head()
# Out:
#               Title                                      Cast and crew  \
# 0       Escape Room  Adam Robitel (director); Bragi F. Schut, Maria...
# 1        Rust Creek  Jen McGowan (director); Julie Lipson (screenpl...
# 2  American Hangman  Wilson Coneybeare (director/screenplay); Donal...
# 3  A Dog's Way Home  Charles Martin Smith (director); W. Bruce Came...
# 4        The Upside  Neil Burger (director); Jon Hartmere (screenpl...
#
#                         genres         director_name         actor_1_name  \
# 0      Horror Thriller Mystery          Adam Robitel       Taylor Russell
# 1  Thriller Drama Action Crime           Jen McGowan    Hermione Corfield
# 2                     Thriller     Wilson Coneybeare    Donald Sutherland
# 3       Drama Adventure Family  Charles Martin Smith  Bryce Dallas Howard
# 4                 Comedy Drama           Neil Burger       Bryan Cranston
#
#          actor_2_name      actor_3_name
# 0        Logan Miller  Deborah Ann Woll
# 1         Jay Paulson      Sean O'Bryan
# 2  Vincent Kartheiser     Oliver Dennis
# 3  Edward James Olmos   Alexandra Shipp
# 4          Kevin Hart     Nicole Kidman

# %%
df_2019 = df_2019.rename(columns={'Title':'movie_title'})

# %%
new_df19 = df_2019.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df19['actor_1_name'] = new_df19['actor_1_name'].replace(np.nan, 'unknown')
new_df19['actor_2_name'] = new_df19['actor_2_name'].replace(np.nan, 'unknown')
new_df19['actor_3_name'] = new_df19['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df19['movie_title'] = new_df19['movie_title'].str.lower()

# %%
new_df19['comb'] = new_df19['actor_1_name'] + ' ' + new_df19['actor_2_name'] + ' '+ new_df19['actor_3_name'] + ' '+ new_df19['director_name'] +' ' + new_df19['genres']
new_df19.head()
# Out:
#           director_name         actor_1_name        actor_2_name  \
# 0          Adam Robitel       Taylor Russell        Logan Miller
# 1           Jen McGowan    Hermione Corfield         Jay Paulson
# 2     Wilson Coneybeare    Donald Sutherland  Vincent Kartheiser
# 3  Charles Martin Smith  Bryce Dallas Howard  Edward James Olmos
# 4           Neil Burger       Bryan Cranston          Kevin Hart
#
#        actor_3_name                       genres       movie_title  \
# 0  Deborah Ann Woll      Horror Thriller Mystery       escape room
# 1      Sean O'Bryan  Thriller Drama Action Crime        rust creek
# 2     Oliver Dennis                     Thriller  american hangman
# 3   Alexandra Shipp       Drama Adventure Family  a dog's way home
# 4     Nicole Kidman                 Comedy Drama        the upside
#
#                                                 comb
# 0  Taylor Russell Logan Miller Deborah Ann Woll A...
# 1  Hermione Corfield Jay Paulson Sean O'Bryan Jen...
# 2  Donald Sutherland Vincent Kartheiser Oliver De...
# 3  Bryce Dallas Howard Edward James Olmos Alexand...
# 4  Bryan Cranston Kevin Hart Nicole Kidman Neil B...

# %%
# Extract Data For 2020 movies
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# <ipython-input-287-ccc3fdad469d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 271  D E C E M B E R         25       We Can Be Heroes
# 272  D E C E M B E R         25      News of the World
# 273  D E C E M B E R         25  One Night in Miami...
# 274  D E C E M B E R         25  Promising Young Woman
# 275  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 271  Netflix / Troublemaker Studios / Double R Prod...
# 272        Universal Pictures / Perfect World Pictures
# 273                                     Amazon Studios
# 274          Focus Features / FilmNation Entertainment
# 275                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 271  Robert Rodriguez (director/screenplay); Priyan...
# 272  Paul Greengrass (director/screenplay); Luke Da...
# 273  Regina King (director); Kemp Powers (screenpla...
# 274  Emerald Fennell (director/screenplay); Carey M...
# 275  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 271  [242]
# 272  [243]
# 273  [244]
# 274  [245]
# 275  [246]
#
# [276 rows x 7 columns]

# %%
def get_genre1(x):
    genres = []
    # Replace 'YOUR_API_KEY' with your actual TMDb API key
    api_key = '55660d08c6027c476324ca215b88fcbc'
    base_url = 'https://api.themoviedb.org/3'

    # Search for the movie
    search_url = f'{base_url}/search/movie'
    params = {'api_key': api_key, 'query': x}
    response = requests.get(search_url, params=params)
    movie_data = response.json()

    if 'results' in movie_data and movie_data['results']:
        movie_id = movie_data['results'][0]['id']
        # Get movie details
        movie_url = f'{base_url}/movie/{movie_id}'
        params = {'api_key': api_key}
        response = requests.get(movie_url, params=params)
        movie_details = response.json()

        if 'genres' in movie_details:
            genre_str = " "
            for genre in movie_details['genres']:
                genres.append(genre['name'])
            return genre_str.join(genres)

    return None

# %%
df['genres'] = df['Title'].map(lambda x: get_genre1(str(x)))
df
# Out:
#              Opening  Opening.1                  Title  \
# 0      J A N U A R Y          3             The Grudge
# 1      J A N U A R Y         10             Underwater
# 2      J A N U A R Y         10            Like a Boss
# 3      J A N U A R Y         10          Three Christs
# 4      J A N U A R Y         10      Inherit the Viper
# ..               ...        ...                    ...
# 271  D E C E M B E R         25       We Can Be Heroes
# 272  D E C E M B E R         25      News of the World
# 273  D E C E M B E R         25  One Night in Miami...
# 274  D E C E M B E R         25  Promising Young Woman
# 275  D E C E M B E R         30      Pieces of a Woman
#
#                                     Production company  \
# 0    Screen Gems / Stage 6 Films / Ghost House Pict...
# 1    20th Century Fox / TSG Entertainment / Chernin...
# 2                   Paramount Pictures / Artists First
# 3                                            IFC Films
# 4       Barry Films / Tycor International Film Company
# ..                                                 ...
# 271  Netflix / Troublemaker Studios / Double R Prod...
# 272        Universal Pictures / Perfect World Pictures
# 273                                     Amazon Studios
# 274          Focus Features / FilmNation Entertainment
# 275                             Netflix / Bron Studios
#
#                                          Cast and crew  \
# 0    Nicolas Pesce (director/screenplay); Andrea Ri...
# 1    William Eubank (director); Brian Duffield, Ada...
# 2    Miguel Arteta (director); Sam Pitman, Adam Col...
# 3    Jon Avnet (director/screenplay); Eric Nazarian...
# 4    Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                                                 ...
# 271  Robert Rodriguez (director/screenplay); Priyan...
# 272  Paul Greengrass (director/screenplay); Luke Da...
# 273  Regina King (director); Kemp Powers (screenpla...
# 274  Emerald Fennell (director/screenplay); Carey M...
# 275  Kornél Mundruczó (director); Kata Wéber (scree...
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  NaN
# 4                                                  [5]
# ..                                                 ...
# 271                                                NaN
# 272                                                NaN
# 273                                                NaN
# 274                                                NaN
# 275                                                NaN
#
#       Ref.                                   genres
# 0      NaN                           Horror Mystery
# 1      NaN  Horror Science Fiction Action Adventure
# 2      NaN                                   Comedy
# 3      NaN                                    Drama
# 4      NaN                     Crime Thriller Drama
# ..     ...                                      ...
# 271  [242]             Family Action Fantasy Comedy
# 272  [243]                  Drama Western Adventure
# 273  [244]                                    Drama
# 274  [245]                     Thriller Crime Drama
# 275  [246]                                    Drama
#
# [276 rows x 8 columns]

# %%
df['Opening']=df['Opening'].str.replace(' ','')

# %%
df_2020 = df[['Title','Cast and crew','genres']]
df_2020
# Out:
#                      Title                                      Cast and crew  \
# 0               The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1               Underwater  William Eubank (director); Brian Duffield, Ada...
# 2              Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3            Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4        Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
# ..                     ...                                                ...
# 271       We Can Be Heroes  Robert Rodriguez (director/screenplay); Priyan...
# 272      News of the World  Paul Greengrass (director/screenplay); Luke Da...
# 273  One Night in Miami...  Regina King (director); Kemp Powers (screenpla...
# 274  Promising Young Woman  Emerald Fennell (director/screenplay); Carey M...
# 275      Pieces of a Woman  Kornél Mundruczó (director); Kata Wéber (scree...
#
#                                       genres
# 0                             Horror Mystery
# 1    Horror Science Fiction Action Adventure
# 2                                     Comedy
# 3                                      Drama
# 4                       Crime Thriller Drama
# ..                                       ...
# 271             Family Action Fantasy Comedy
# 272                  Drama Western Adventure
# 273                                    Drama
# 274                     Thriller Crime Drama
# 275                                    Drama
#
# [276 rows x 3 columns]

# %%
# Extract Directors
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-294-0d29c98c2cf5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['director_name'] = df_2020['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                     genres   director_name
# 0                           Horror Mystery   Nicolas Pesce
# 1  Horror Science Fiction Action Adventure  William Eubank
# 2                                   Comedy   Miguel Arteta
# 3                                    Drama       Jon Avnet
# 4                     Crime Thriller Drama  Anthony Jerjen

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-297-da3b02104b70>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_1_name'] = df_2020['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-299-4182ad640e21>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_2_name'] = df_2020['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-301-c68483737dab>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2020['actor_3_name'] = df_2020['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2020.head()
# Out:
#                Title                                      Cast and crew  \
# 0         The Grudge  Nicolas Pesce (director/screenplay); Andrea Ri...
# 1         Underwater  William Eubank (director); Brian Duffield, Ada...
# 2        Like a Boss  Miguel Arteta (director); Sam Pitman, Adam Col...
# 3      Three Christs  Jon Avnet (director/screenplay); Eric Nazarian...
# 4  Inherit the Viper  Anthony Jerjen (director); Andrew Crabtree (sc...
#
#                                     genres   director_name  \
# 0                           Horror Mystery   Nicolas Pesce
# 1  Horror Science Fiction Action Adventure  William Eubank
# 2                                   Comedy   Miguel Arteta
# 3                                    Drama       Jon Avnet
# 4                     Crime Thriller Drama  Anthony Jerjen
#
#          actor_1_name       actor_2_name     actor_3_name
# 0  Andrea Riseborough      Demián Bichir         John Cho
# 1     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3        Richard Gere     Peter Dinklage   Walton Goggins
# 4       Josh Hartnett  Margarita Levieva   Chandler Riggs

# %%
df_2020 = df_2020.rename(columns={'Title':'movie_title'})

# %%
new_df20 = df_2020.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df20['actor_1_name'] = new_df20['actor_1_name'].replace(np.nan, 'unknown')
new_df20['actor_2_name'] = new_df20['actor_2_name'].replace(np.nan, 'unknown')
new_df20['actor_3_name'] = new_df20['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df20['movie_title'] = new_df20['movie_title'].str.lower()

# %%
new_df20['comb'] = new_df20['actor_1_name'] + ' ' + new_df20['actor_2_name'] + ' '+ new_df20['actor_3_name'] + ' '+ new_df20['director_name'] +' ' + new_df20['genres']
new_df20.head()
# Out:
#     director_name        actor_1_name       actor_2_name     actor_3_name  \
# 0   Nicolas Pesce  Andrea Riseborough      Demián Bichir         John Cho
# 1  William Eubank     Kristen Stewart     Vincent Cassel  Jessica Henwick
# 2   Miguel Arteta     Tiffany Haddish         Rose Byrne      Salma Hayek
# 3       Jon Avnet        Richard Gere     Peter Dinklage   Walton Goggins
# 4  Anthony Jerjen       Josh Hartnett  Margarita Levieva   Chandler Riggs
#
#                                     genres        movie_title  \
# 0                           Horror Mystery         the grudge
# 1  Horror Science Fiction Action Adventure         underwater
# 2                                   Comedy        like a boss
# 3                                    Drama      three christs
# 4                     Crime Thriller Drama  inherit the viper
#
#                                                 comb
# 0  Andrea Riseborough Demián Bichir John Cho Nico...
# 1  Kristen Stewart Vincent Cassel Jessica Henwick...
# 2  Tiffany Haddish Rose Byrne Salma Hayek Miguel ...
# 3  Richard Gere Peter Dinklage Walton Goggins Jon...
# 4  Josh Hartnett Margarita Levieva Chandler Riggs...

# %%
# Extract Data For 2021 movies
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# <ipython-input-309-ccc3fdad469d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#              Opening  Opening.1                   Title  \
# 0      J A N U A R Y        1.0     Shadow in the Cloud
# 1      J A N U A R Y        5.0                 Hacksaw
# 2      J A N U A R Y       13.0         The White Tiger
# 3      J A N U A R Y       14.0             Locked Down
# 4      J A N U A R Y       15.0                 The Dig
# ..               ...        ...                     ...
# 357  D E C E M B E R       25.0  The Tragedy of Macbeth
# 358  D E C E M B E R       25.0    A Journal for Jordan
# 359  D E C E M B E R       25.0       American Underdog
# 360  D E C E M B E R       26.0                 Memoria
# 361  D E C E M B E R        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                     Leone Films / Midnight Releasing
# 2                                Netflix / Noruz Films
# 3                      HBO Max / Warner Bros. Pictures
# 4                          Netflix / Clerkenwell Films
# ..                                                 ...
# 357                        Apple TV+ / A24 / IAC Films
# 358  Columbia Pictures / Escape Artists / Bron Studios
# 359                                          Lionsgate
# 360                                               Neon
# 361                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Ramin Bahrani (director/screenplay); Adarsh Go...
# 3    Doug Liman (director); Steven Knight (screenpl...
# 4    Simon Stone (director); Moira Buffini (screenp...
# ..                                                 ...
# 357  Joel Coen (director/screenplay); Denzel Washin...
# 358  Denzel Washington (director); Virgil Williams ...
# 359  Erwin brothers (directors); Jon Erwin, David A...
# 360  Apichatpong Weerasethakul (director/acreenplay...
# 361                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  NaN
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
# 361                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 357  [274]
# 358  [275]
# 359  [276]
# 360  [277]
# 361    NaN
#
# [362 rows x 7 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre1(str(x)))
df
# Out:
#              Opening  Opening.1                   Title  \
# 0      J A N U A R Y        1.0     Shadow in the Cloud
# 1      J A N U A R Y        5.0                 Hacksaw
# 2      J A N U A R Y       13.0         The White Tiger
# 3      J A N U A R Y       14.0             Locked Down
# 4      J A N U A R Y       15.0                 The Dig
# ..               ...        ...                     ...
# 357  D E C E M B E R       25.0  The Tragedy of Macbeth
# 358  D E C E M B E R       25.0    A Journal for Jordan
# 359  D E C E M B E R       25.0       American Underdog
# 360  D E C E M B E R       26.0                 Memoria
# 361  D E C E M B E R        NaN                     NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                     Leone Films / Midnight Releasing
# 2                                Netflix / Noruz Films
# 3                      HBO Max / Warner Bros. Pictures
# 4                          Netflix / Clerkenwell Films
# ..                                                 ...
# 357                        Apple TV+ / A24 / IAC Films
# 358  Columbia Pictures / Escape Artists / Bron Studios
# 359                                          Lionsgate
# 360                                               Neon
# 361                                                NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Ramin Bahrani (director/screenplay); Adarsh Go...
# 3    Doug Liman (director); Steven Knight (screenpl...
# 4    Simon Stone (director); Moira Buffini (screenp...
# ..                                                 ...
# 357  Joel Coen (director/screenplay); Denzel Washin...
# 358  Denzel Washington (director); Virgil Williams ...
# 359  Erwin brothers (directors); Jon Erwin, David A...
# 360  Apichatpong Weerasethakul (director/acreenplay...
# 361                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  NaN
# 3                                                  [4]
# 4                                                  [5]
# ..                                                 ...
# 357                                                NaN
# 358                                                NaN
# 359                                                NaN
# 360                                                NaN
# 361                                                NaN
#
#       Ref.                         genres
# 0      NaN              Horror Action War
# 1      NaN                         Horror
# 2      NaN                          Drama
# 3      NaN             Comedy Crime Drama
# 4      NaN                  Drama History
# ..     ...                            ...
# 357  [274]                      Drama War
# 358  [275]                  Drama Romance
# 359  [276]                          Drama
# 360  [277]  Drama Science Fiction Mystery
# 361    NaN                    Drama Crime
#
# [362 rows x 8 columns]

# %%
df['Opening']=df['Opening'].str.replace(' ','')

# %%
df_2021 = df[['Title','Cast and crew','genres']]
df_2021
# Out:
#                       Title  \
# 0       Shadow in the Cloud
# 1                   Hacksaw
# 2           The White Tiger
# 3               Locked Down
# 4                   The Dig
# ..                      ...
# 357  The Tragedy of Macbeth
# 358    A Journal for Jordan
# 359       American Underdog
# 360                 Memoria
# 361                     NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Ramin Bahrani (director/screenplay); Adarsh Go...
# 3    Doug Liman (director); Steven Knight (screenpl...
# 4    Simon Stone (director); Moira Buffini (screenp...
# ..                                                 ...
# 357  Joel Coen (director/screenplay); Denzel Washin...
# 358  Denzel Washington (director); Virgil Williams ...
# 359  Erwin brothers (directors); Jon Erwin, David A...
# 360  Apichatpong Weerasethakul (director/acreenplay...
# 361                                                NaN
#
#                             genres
# 0                Horror Action War
# 1                           Horror
# 2                            Drama
# 3               Comedy Crime Drama
# 4                    Drama History
# ..                             ...
# 357                      Drama War
# 358                  Drama Romance
# 359                          Drama
# 360  Drama Science Fiction Mystery
# 361                    Drama Crime
#
# [362 rows x 3 columns]

# %%
df_2021.dropna(how='any',inplace=True)
# Out:
# <ipython-input-315-5e915c7e2f99>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021.dropna(how='any',inplace=True)

# %%
# Extract Directors
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-317-4669cbb2185b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(x))

# %%
df_2021.head()
# Out:
#                  Title                                      Cast and crew  \
# 0  Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1              Hacksaw  Anthony Leone (director/screenplay); Amy Cay, ...
# 2      The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 3          Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 4              The Dig  Simon Stone (director); Moira Buffini (screenp...
#
#                genres   director_name
# 0   Horror Action War  Roseanne Liang
# 1              Horror   Anthony Leone
# 2               Drama   Ramin Bahrani
# 3  Comedy Crime Drama      Doug Liman
# 4       Drama History     Simon Stone

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-320-bf0437ae2187>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-322-64783237bae2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-324-979f1e440eff>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2021.head()
# Out:
#                  Title                                      Cast and crew  \
# 0  Shadow in the Cloud  Roseanne Liang (director/screenplay); Max Land...
# 1              Hacksaw  Anthony Leone (director/screenplay); Amy Cay, ...
# 2      The White Tiger  Ramin Bahrani (director/screenplay); Adarsh Go...
# 3          Locked Down  Doug Liman (director); Steven Knight (screenpl...
# 4              The Dig  Simon Stone (director); Moira Buffini (screenp...
#
#                genres   director_name        actor_1_name  \
# 0   Horror Action War  Roseanne Liang  Chloë Grace Moretz
# 1              Horror   Anthony Leone             Amy Cay
# 2               Drama   Ramin Bahrani       Adarsh Gourav
# 3  Comedy Crime Drama      Doug Liman       Anne Hathaway
# 4       Drama History     Simon Stone      Carey Mulligan
#
#            actor_2_name           actor_3_name
# 0     Taylor John Smith           Beulah Koale
# 1  Brian Patrick Butler     Michael C. Burgess
# 2         Rajkummar Rao  Priyanka Chopra Jonas
# 3      Chiwetel Ejiofor       Stephen Merchant
# 4         Ralph Fiennes             Lily James

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21['actor_1_name'] = new_df21['actor_1_name'].replace(np.nan, 'unknown')
new_df21['actor_2_name'] = new_df21['actor_2_name'].replace(np.nan, 'unknown')
new_df21['actor_3_name'] = new_df21['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']
new_df21.head()
# Out:
#     director_name        actor_1_name          actor_2_name  \
# 0  Roseanne Liang  Chloë Grace Moretz     Taylor John Smith
# 1   Anthony Leone             Amy Cay  Brian Patrick Butler
# 2   Ramin Bahrani       Adarsh Gourav         Rajkummar Rao
# 3      Doug Liman       Anne Hathaway      Chiwetel Ejiofor
# 4     Simon Stone      Carey Mulligan         Ralph Fiennes
#
#             actor_3_name              genres          movie_title  \
# 0           Beulah Koale   Horror Action War  shadow in the cloud
# 1     Michael C. Burgess              Horror              hacksaw
# 2  Priyanka Chopra Jonas               Drama      the white tiger
# 3       Stephen Merchant  Comedy Crime Drama          locked down
# 4             Lily James       Drama History              the dig
#
#                                                 comb
# 0  Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1  Amy Cay Brian Patrick Butler Michael C. Burges...
# 2  Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 3  Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# 4  Carey Mulligan Ralph Fiennes Lily James Simon ...

# %%
# Extract Data For 2022 movies
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2022"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# <ipython-input-332-ccc3fdad469d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#              Opening  Opening.1                     Title  \
# 0      J A N U A R Y        7.0                   The 355
# 1      J A N U A R Y        7.0  The Legend of La Llorona
# 2      J A N U A R Y        7.0              The Commando
# 3      J A N U A R Y        7.0            American Siege
# 4      J A N U A R Y       14.0                    Scream
# ..               ...        ...                       ...
# 327  D E C E M B E R       30.0            Alice, Darling
# 328  D E C E M B E R        NaN                       NaN
# 329  D E C E M B E R        NaN                       NaN
# 330  D E C E M B E R        NaN                       NaN
# 331  D E C E M B E R        NaN                       NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# 3                               Vertical Entertainment
# 4    Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                 ...
# 327                     Lionsgate / Elevation Pictures
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#       Ref.
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# ..     ...
# 327  [264]
# 328    NaN
# 329    NaN
# 330    NaN
# 331    NaN
#
# [332 rows x 7 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre1(str(x)))
df
# Out:
#              Opening  Opening.1                     Title  \
# 0      J A N U A R Y        7.0                   The 355
# 1      J A N U A R Y        7.0  The Legend of La Llorona
# 2      J A N U A R Y        7.0              The Commando
# 3      J A N U A R Y        7.0            American Siege
# 4      J A N U A R Y       14.0                    Scream
# ..               ...        ...                       ...
# 327  D E C E M B E R       30.0            Alice, Darling
# 328  D E C E M B E R        NaN                       NaN
# 329  D E C E M B E R        NaN                       NaN
# 330  D E C E M B E R        NaN                       NaN
# 331  D E C E M B E R        NaN                       NaN
#
#                                     Production company  \
# 0    Universal Pictures / Freckle Films / FilmNatio...
# 1                       Saban Films / Ageless Pictures
# 2                 Saban Films / Premiere Entertainment
# 3                               Vertical Entertainment
# 4    Paramount Pictures / Spyglass Media Group / Ra...
# ..                                                 ...
# 327                     Lionsgate / Elevation Pictures
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#     .mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Ref.  \
# 0                                                  [2]
# 1                                                  [3]
# 2                                                  [4]
# 3                                                  [5]
# 4                                                  [6]
# ..                                                 ...
# 327                                                NaN
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#       Ref.                                         genres
# 0      NaN                                Action Thriller
# 1      NaN  Family Animation Fantasy Horror Comedy Action
# 2      NaN                          Action Crime Thriller
# 3      NaN                      Action Adventure Thriller
# 4      NaN                        Horror Mystery Thriller
# ..     ...                                            ...
# 327  [264]                                 Thriller Drama
# 328    NaN                                    Drama Crime
# 329    NaN                                    Drama Crime
# 330    NaN                                    Drama Crime
# 331    NaN                                    Drama Crime
#
# [332 rows x 8 columns]

# %%
df['Opening']=df['Opening'].str.replace(' ','')

# %%
df_2022 = df[['Title','Cast and crew','genres']]
df_2022
# Out:
#                         Title  \
# 0                     The 355
# 1    The Legend of La Llorona
# 2                The Commando
# 3              American Siege
# 4                      Scream
# ..                        ...
# 327            Alice, Darling
# 328                       NaN
# 329                       NaN
# 330                       NaN
# 331                       NaN
#
#                                          Cast and crew  \
# 0    Simon Kinberg (director/screenplay); Theresa R...
# 1    Patricia Harris Seeley (director/screenplay); ...
# 2    Asif Akbar (director); Koji Steven Sakai (scre...
# 3    Edward Drake (director/screenplay); Timothy V....
# 4    Matt Bettinelli-Olpin, Tyler Gillett (director...
# ..                                                 ...
# 327  Mary Nighy (director); Alanna Francis (screenp...
# 328                                                NaN
# 329                                                NaN
# 330                                                NaN
# 331                                                NaN
#
#                                             genres
# 0                                  Action Thriller
# 1    Family Animation Fantasy Horror Comedy Action
# 2                            Action Crime Thriller
# 3                        Action Adventure Thriller
# 4                          Horror Mystery Thriller
# ..                                             ...
# 327                                 Thriller Drama
# 328                                    Drama Crime
# 329                                    Drama Crime
# 330                                    Drama Crime
# 331                                    Drama Crime
#
# [332 rows x 3 columns]

# %%
df_2022.dropna(how='any',inplace=True)
# Out:
# <ipython-input-337-f93e1dc37298>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022.dropna(how='any',inplace=True)

# %%
# Extract Directors
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-339-82698347c6e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['director_name'] = df_2022['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-341-c107d38851f7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_1_name'] = df_2022['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-343-da18e330aae0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_2_name'] = df_2022['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-345-dff1896922fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2022['actor_3_name'] = df_2022['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2022.head()
# Out:
#                       Title  \
# 0                   The 355
# 1  The Legend of La Llorona
# 2              The Commando
# 3            American Siege
# 4                    Scream
#
#                                        Cast and crew  \
# 0  Simon Kinberg (director/screenplay); Theresa R...
# 1  Patricia Harris Seeley (director/screenplay); ...
# 2  Asif Akbar (director); Koji Steven Sakai (scre...
# 3  Edward Drake (director/screenplay); Timothy V....
# 4  Matt Bettinelli-Olpin, Tyler Gillett (director...
#
#                                           genres  \
# 0                                Action Thriller
# 1  Family Animation Fantasy Horror Comedy Action
# 2                          Action Crime Thriller
# 3                      Action Adventure Thriller
# 4                        Horror Mystery Thriller
#
#                           director_name       actor_1_name       actor_2_name  \
# 0                         Simon Kinberg   Jessica Chastain     Lupita Nyong'o
# 1                Patricia Harris Seeley      Autumn Reeser       Antonio Cupo
# 2                            Asif Akbar      Mickey Rourke  Michael Jai White
# 3                          Edward Drake  Timothy V. Murphy       Bruce Willis
# 4  Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera      Mason Gooding
#
#     actor_3_name
# 0  Penélope Cruz
# 1    Danny Trejo
# 2            NaN
# 3            NaN
# 4   Jenna Ortega

# %%
df_2022 = df_2022.rename(columns={'Title':'movie_title'})

# %%
new_df22 = df_2022.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df22['actor_1_name'] = new_df22['actor_1_name'].replace(np.nan, 'unknown')
new_df22['actor_2_name'] = new_df22['actor_2_name'].replace(np.nan, 'unknown')
new_df22['actor_3_name'] = new_df22['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df22['movie_title'] = new_df22['movie_title'].str.lower()

# %%
new_df22['comb'] = new_df22['actor_1_name'] + ' ' + new_df22['actor_2_name'] + ' '+ new_df22['actor_3_name'] + ' '+ new_df22['director_name'] +' ' + new_df22['genres']
new_df22.head()
# Out:
#                           director_name       actor_1_name       actor_2_name  \
# 0                         Simon Kinberg   Jessica Chastain     Lupita Nyong'o
# 1                Patricia Harris Seeley      Autumn Reeser       Antonio Cupo
# 2                            Asif Akbar      Mickey Rourke  Michael Jai White
# 3                          Edward Drake  Timothy V. Murphy       Bruce Willis
# 4  Matt Bettinelli-Olpin, Tyler Gillett    Melissa Barrera      Mason Gooding
#
#     actor_3_name                                         genres  \
# 0  Penélope Cruz                                Action Thriller
# 1    Danny Trejo  Family Animation Fantasy Horror Comedy Action
# 2        unknown                          Action Crime Thriller
# 3        unknown                      Action Adventure Thriller
# 4   Jenna Ortega                        Horror Mystery Thriller
#
#                 movie_title                                               comb
# 0                   the 355  Jessica Chastain Lupita Nyong'o Penélope Cruz ...
# 1  the legend of la llorona  Autumn Reeser Antonio Cupo Danny Trejo Patrici...
# 2              the commando  Mickey Rourke Michael Jai White unknown Asif A...
# 3            american siege  Timothy V. Murphy Bruce Willis unknown Edward ...
# 4                    scream  Melissa Barrera Mason Gooding Jenna Ortega Mat...

# %%
# Extract Data For 2023 movies
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
df
# Out:
# <ipython-input-353-ccc3fdad469d>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)
#      Rank                                Title   Distributor Domestic gross  \
# 0     1.0                               Barbie  Warner Bros.   $634,309,238
# 1     2.0          The Super Mario Bros. Movie     Universal   $574,930,640
# 2     3.0  Spider-Man: Across the Spider-Verse          Sony   $381,311,319
# 3     4.0       Guardians of the Galaxy Vol. 3        Disney   $358,995,815
# 4     5.0                          Oppenheimer     Universal   $323,166,815
# ..    ...                                  ...           ...            ...
# 235   NaN                            Fair Play           NaN            NaN
# 236   NaN                             Heist 88           NaN            NaN
# 237   NaN     The Re-Education of Molly Singer           NaN            NaN
# 238   NaN                           Deliver Us           NaN            NaN
# 239   NaN                                  NaN           NaN            NaN
#
#                Opening  Opening.1                    Production company  \
# 0                  NaN        NaN                                   NaN
# 1                  NaN        NaN                                   NaN
# 2                  NaN        NaN                                   NaN
# 3                  NaN        NaN                                   NaN
# 4                  NaN        NaN                                   NaN
# ..                 ...        ...                                   ...
# 235  S E P T E M B E R       29.0  Netflix / MRC / T-Street Productions
# 236  S E P T E M B E R       29.0                 Showtime / Paramount+
# 237  S E P T E M B E R       29.0                             Lionsgate
# 238  S E P T E M B E R       29.0                      Magnet Releasing
# 239  S E P T E M B E R        NaN                                   NaN
#
#                                          Cast and crew   Ref.
# 0                                                  NaN    NaN
# 1                                                  NaN    NaN
# 2                                                  NaN    NaN
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 235  Chloe Domont (director/screenplay); Phoebe Dyn...  [214]
# 236  Menhaj Huda (director); Dwayne Johnson-Cochran...  [215]
# 237  Andy Palmer (director); Todd Friedman, Kevin H...  [216]
# 238  Lee Roy Kunz, Cru Ennis (directors); Lee Roy K...  [217]
# 239                                                NaN    NaN
#
# [240 rows x 9 columns]

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))
df
# Out:
#      Rank                                Title   Distributor Domestic gross  \
# 0     1.0                               Barbie  Warner Bros.   $634,309,238
# 1     2.0          The Super Mario Bros. Movie     Universal   $574,930,640
# 2     3.0  Spider-Man: Across the Spider-Verse          Sony   $381,311,319
# 3     4.0       Guardians of the Galaxy Vol. 3        Disney   $358,995,815
# 4     5.0                          Oppenheimer     Universal   $323,166,815
# ..    ...                                  ...           ...            ...
# 235   NaN                            Fair Play           NaN            NaN
# 236   NaN                             Heist 88           NaN            NaN
# 237   NaN     The Re-Education of Molly Singer           NaN            NaN
# 238   NaN                           Deliver Us           NaN            NaN
# 239   NaN                                  NaN           NaN            NaN
#
#                Opening  Opening.1                    Production company  \
# 0                  NaN        NaN                                   NaN
# 1                  NaN        NaN                                   NaN
# 2                  NaN        NaN                                   NaN
# 3                  NaN        NaN                                   NaN
# 4                  NaN        NaN                                   NaN
# ..                 ...        ...                                   ...
# 235  S E P T E M B E R       29.0  Netflix / MRC / T-Street Productions
# 236  S E P T E M B E R       29.0                 Showtime / Paramount+
# 237  S E P T E M B E R       29.0                             Lionsgate
# 238  S E P T E M B E R       29.0                      Magnet Releasing
# 239  S E P T E M B E R        NaN                                   NaN
#
#                                          Cast and crew   Ref.  \
# 0                                                  NaN    NaN
# 1                                                  NaN    NaN
# 2                                                  NaN    NaN
# 3                                                  NaN    NaN
# 4                                                  NaN    NaN
# ..                                                 ...    ...
# 235  Chloe Domont (director/screenplay); Phoebe Dyn...  [214]
# 236  Menhaj Huda (director); Dwayne Johnson-Cochran...  [215]
# 237  Andy Palmer (director); Todd Friedman, Kevin H...  [216]
# 238  Lee Roy Kunz, Cru Ennis (directors); Lee Roy K...  [217]
# 239                                                NaN    NaN
#
#                                         genres
# 0                     Comedy Adventure Fantasy
# 1    Animation Family Adventure Fantasy Comedy
# 2                   Animation Action Adventure
# 3             Science Fiction Adventure Action
# 4                                Drama History
# ..                                         ...
# 235                             Thriller Drama
# 236                                Crime Drama
# 237                                     Comedy
# 238                                     Horror
# 239                                Drama Crime
#
# [240 rows x 10 columns]

# %%
df['Opening']=df['Opening'].str.replace(' ','')

# %%
df_2023 = df[['Title','Cast and crew','genres']]
df_2023
# Out:
#                                    Title  \
# 0                                 Barbie
# 1            The Super Mario Bros. Movie
# 2    Spider-Man: Across the Spider-Verse
# 3         Guardians of the Galaxy Vol. 3
# 4                            Oppenheimer
# ..                                   ...
# 235                            Fair Play
# 236                             Heist 88
# 237     The Re-Education of Molly Singer
# 238                           Deliver Us
# 239                                  NaN
#
#                                          Cast and crew  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 235  Chloe Domont (director/screenplay); Phoebe Dyn...
# 236  Menhaj Huda (director); Dwayne Johnson-Cochran...
# 237  Andy Palmer (director); Todd Friedman, Kevin H...
# 238  Lee Roy Kunz, Cru Ennis (directors); Lee Roy K...
# 239                                                NaN
#
#                                         genres
# 0                     Comedy Adventure Fantasy
# 1    Animation Family Adventure Fantasy Comedy
# 2                   Animation Action Adventure
# 3             Science Fiction Adventure Action
# 4                                Drama History
# ..                                         ...
# 235                             Thriller Drama
# 236                                Crime Drama
# 237                                     Comedy
# 238                                     Horror
# 239                                Drama Crime
#
# [240 rows x 3 columns]

# %%
df_2023.dropna(how='any',inplace=True)
# Out:
# <ipython-input-357-4baeb48dabe7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023.dropna(how='any',inplace=True)

# %%
# Extract Directors
def get_director(x):
    if " (director)" in x: #we are getting "director"
        return x.split(" (director)")[0]
    elif " (directors)" in x: #we are getting "directors" with "s"
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0] #we are getting "directors/screenplay"

# %%
df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(x))
# Out:
# <ipython-input-359-bf552045c0c3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(x))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(x))
# Out:
# <ipython-input-361-bcbd61cbd292>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(x))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2(x))
# Out:
# <ipython-input-363-5054af5e8e9b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2(x))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3(x))
# Out:
# <ipython-input-365-a01f469aa2d8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3(x))

# %%
df_2023.head()
# Out:
#                    Title                                      Cast and crew  \
# 10                 M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 11           The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 12  The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 13                 Plane  Jean-François Richet (director); Charles Cummi...
# 14           House Party  Calmatic (director); Jamal Olori, Stephen Glov...
#
#                                      genres         director_name  \
# 10                   Science Fiction Horror      Gerard Johnstone
# 11                                  Western         Brett Donowho
# 12  Horror Fantasy Science Fiction Thriller     Nathan Frankowski
# 13                Action Adventure Thriller  Jean-François Richet
# 14                                   Comedy              Calmatic
#
#         actor_1_name          actor_2_name  actor_3_name
# 10  Allison Williams         Violet McGraw   Amie Donald
# 11      Nicolas Cage  Ryan Kiera Armstrong           NaN
# 12   Alice Orr-Ewing             Joe Doyle  Eveline Hall
# 13     Gerard Butler           Mike Colter      Yoson An
# 14        Tosin Cole        Jacob Latimore  Karen Obilom

# %%
df_2023 = df_2023.rename(columns={'Title':'movie_title'})

# %%
new_df23 = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df23['actor_1_name'] = new_df23['actor_1_name'].replace(np.nan, 'unknown')
new_df23['actor_2_name'] = new_df23['actor_2_name'].replace(np.nan, 'unknown')
new_df23['actor_3_name'] = new_df23['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_df23['movie_title'] = new_df23['movie_title'].str.lower()

# %%
new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']
new_df23.head()
# Out:
#            director_name      actor_1_name          actor_2_name  \
# 10      Gerard Johnstone  Allison Williams         Violet McGraw
# 11         Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 12     Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 13  Jean-François Richet     Gerard Butler           Mike Colter
# 14              Calmatic        Tosin Cole        Jacob Latimore
#
#     actor_3_name                                   genres  \
# 10   Amie Donald                   Science Fiction Horror
# 11       unknown                                  Western
# 12  Eveline Hall  Horror Fantasy Science Fiction Thriller
# 13      Yoson An                Action Adventure Thriller
# 14  Karen Obilom                                   Comedy
#
#              movie_title                                               comb
# 10                 m3gan  Allison Williams Violet McGraw Amie Donald Ger...
# 11           the old way  Nicolas Cage Ryan Kiera Armstrong unknown Bret...
# 12  the devil conspiracy  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 13                 plane  Gerard Butler Mike Colter Yoson An Jean-Franço...
# 14           house party  Tosin Cole Jacob Latimore Karen Obilom Calmati...

# %%
my_df=new_df18.append(new_df19.append(new_df20.append(new_df21.append(new_df22.append(new_df23),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)
# Out:
# <ipython-input-372-a19f186519e8>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df=new_df18.append(new_df19.append(new_df20.append(new_df21.append(new_df22.append(new_df23),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)
# <ipython-input-372-a19f186519e8>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   my_df=new_df18.append(new_df19.append(new_df20.append(new_df21.append(new_df22.append(new_df23),ignore_index=True),ignore_index=True),ignore_index=True),ignore_index=True)

# %%
old_df = pd.read_csv('/content/new_data.csv')
old_df
# Out:
#               director_name          actor_1_name            actor_2_name  \
# 0             James Cameron           CCH Pounder        Joel David Moore
# 1            Gore Verbinski           Johnny Depp           Orlando Bloom
# 2                Sam Mendes       Christoph Waltz            Rory Kinnear
# 3         Christopher Nolan             Tom Hardy          Christian Bale
# 4               Doug Walker           Doug Walker              Rob Walker
# ...                     ...                   ...                     ...
# 5496            Jim Strouse      Jessica Williams            Chris O'Dowd
# 5497            Farhad Mann         Adelaide Kane  Benjamin Hollingsworth
# 5498       Hannaleena Hauru        Inka Haapamäki           Rosa Honkonen
# 5499  Jonathan A. Rosenbaum  Lou Diamond Phillips           Wallace Shawn
# 5500           Ravi Udyawar        Sridevi Kapoor               Sajal Ali
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 5496       Keith Stanfield                   Romance Comedy
# 5497     Jean Louisa Kelly                          Romance
# 5498        Tiitus Rantala                   Romance Comedy
# 5499           Gina Holden       Crime Comedy Action Family
# 5500        Akshaye Khanna             Crime Drama Thriller
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 5496                       the incredible jessica james
# 5497                                  can't buy my love
# 5498                   thick lashes of lauri mäntyvaara
# 5499                        cop and a half: new recruit
# 5500                                                mom
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 5496  Jessica Williams Chris O'Dowd Keith Stanfield ...
# 5497  Adelaide Kane Benjamin Hollingsworth Jean Loui...
# 5498  Inka Haapamäki Rosa Honkonen Tiitus Rantala Ha...
# 5499  Lou Diamond Phillips Wallace Shawn Gina Holden...
# 5500  Sridevi Kapoor Sajal Ali Akshaye Khanna Ravi U...
#
# [5501 rows x 7 columns]

# %%
final_df = old_df.append(my_df,ignore_index=True)
final_df
# Out:
# <ipython-input-375-125d99a9e116>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final_df = old_df.append(my_df,ignore_index=True)
#                 director_name       actor_1_name      actor_2_name  \
# 0               James Cameron        CCH Pounder  Joel David Moore
# 1              Gore Verbinski        Johnny Depp     Orlando Bloom
# 2                  Sam Mendes    Christoph Waltz      Rory Kinnear
# 3           Christopher Nolan          Tom Hardy    Christian Bale
# 4                 Doug Walker        Doug Walker        Rob Walker
# ...                       ...                ...               ...
# 7211           Kevin Greutert         Tobin Bell     Shawnee Smith
# 7212             Chloe Domont     Phoebe Dynevor  Alden Ehrenreich
# 7213              Menhaj Huda  Courtney B. Vance      Keesha Sharp
# 7214              Andy Palmer    Britt Robertson       Ty Simpkins
# 7215  Lee Roy Kunz, Cru Ennis       Lee Roy Kunz  Maria Vera Ratti
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 7211   Synnøve Macody Lund                  Horror Thriller
# 7212          Eddie Marsan                   Thriller Drama
# 7213           Keith David                      Crime Drama
# 7214           Nico Santos                           Comedy
# 7215      Alexander Siddig                           Horror
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7211                                              saw x
# 7212                                          fair play
# 7213                                           heist 88
# 7214                   the re-education of molly singer
# 7215                                         deliver us
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7211  Tobin Bell Shawnee Smith Synnøve Macody Lund K...
# 7212  Phoebe Dynevor Alden Ehrenreich Eddie Marsan C...
# 7213  Courtney B. Vance Keesha Sharp Keith David Men...
# 7214  Britt Robertson Ty Simpkins Nico Santos Andy P...
# 7215  Lee Roy Kunz Maria Vera Ratti Alexander Siddig...
#
# [7216 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           2
# movie_title      0
# comb             2
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isnull().sum().sum()
# Out:
# 0

# %%
final_df.to_csv('final_data.csv',index=False)
